# %% [markdown]
# # Naive bayes

# %%
import re
import glob 
import math

from collections import defaultdict
from pprint import pprint
from sklearn.metrics import confusion_matrix, f1_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Dataset
# Here we have downloaded a dataset from SpamAssassin

# %%
path = './dataset/*/*/*'  # wildcard, glob argument, indicates path for files
data = []

# %%
for fn in glob.glob(path)[:5]: 
    with open(fn, 'r') as file:
        pprint(file.read())
# Out:
# ('Received: from mail.ilxresorts.com (mail.ilxresorts.com [207.108.153.250])\n'
#  '\tby linux.midrange.com (8.11.6/8.11.6) with ESMTP id g6MJU8e16448\n'
#  '\tfor <gibbs@midrange.com>; Mon, 22 Jul 2002 14:30:09 -0500\n'
#  'Received: from ilx2kweb (www.ilxresorts.com [207.108.153.247])\n'
#  '\tby mail.ilxresorts.com (8.9.3/8.9.3) with SMTP id NAA01973\n'
#  '\tfor <gibbs@midrange.com>; Mon, 22 Jul 2002 13:20:35 -0700\n'
#  'From: blowdamovie@atlas.cz\n'
#  'Message-Id: <200207222020.NAA01973@mail.ilxresorts.com>\n'
#  'X-Mailer: DevMailer v1.0 (http://www.geocel.com/devmailer/)\n'
#  'Date: Mon, 22 Jul 2002 12:37:15 US Mountain Standard Time\n'
#  'To: gibbs@midrange.com\n'
#  'Subject: Life-Time upgrades for FREEq4i1i6p8\n'
#  'MIME-Version: 1.0\n'
#  'Content-type: multipart/mixed; boundary="#DM659823986#"\n'
#  'X-Status: \n'
#  'X-Keywords: \n'
#  '\n'
#  '\n'
#  '--#DM659823986#\n'
#  'Content-Type: text/plain; charset=us-ascii\n'
#  'Content-Transfer-Encoding: quoted-printable\n'
#  '\n'
#  'Below is the result of your feedback form.  It was submitted by\n'
#  ' (blowdamovie@atlas.cz) on Monday, July 22, 2002 at 12:37:15\n'
#  '---------------------------------------------------------------------------\n'
#  '\n'
#  ': Why Spend upwards of $4000 on a DVD Burner when we will show you an '
#  'alternative that will do the exact same thing for just a fraction of the '
#  "cost? Copy your DVD's NOW. Best Price on the net. Click here: "
#  'http://010@www.dvdcopyxp.com/cgi-bin/enter.cgi?marketing_id=dcx007 Click to '
#  'remove http://011@www.spambites.com/cgi-bin/enter.cgi?spambytes_id=100115 \n'
#  '\n'
#  '---------------------------------------------------------------------------\n'
#  '\n'
#  '\n'
#  '--#DM659823986#--\n'
#  '\n')
# ('From SpecialBuy@tuxtla.com  Mon Jun 24 17:54:27 2002\n'
#  'Return-Path: SpecialBuy@tuxtla.com\n'
#  'Delivery-Date: Tue Jun  4 12:37:05 2002\n'
#  'Received: from mandark.labs.netnoteinc.com ([213.105.180.140]) by\n'
#  '    dogma.slashnull.org (8.11.6/8.11.6) with ESMTP id g54Bb0O02407 for\n'
#  '    <jm@jmason.org>; Tue, 4 Jun 2002 12:37:00 +0100\n'
#  'Received: from exchange.bschk.com.cn ([210.21.29.230]) by\n'
#  '    mandark.labs.netnoteinc.com (8.11.2/8.11.2) with ESMTP id g54Bas731025;\n'
#  '    Tue, 4 Jun 2002 12:36:58 +0100\n'
#  'Received: from chinanew.com (WWW [61.133.87.195]) by exchange.bschk.com.cn\n'
#  '    with SMTP (Microsoft Exchange Internet Mail Service Version '
#  '5.5.2653.13)\n'
#  '    id LTKXR92B; Tue, 4 Jun 2002 19:35:14 +0800\n'
#  'Message-Id: <000041961b90$000039ce$00005612@tlaxcala.com>\n'
#  'To: <engineer@netnovations.com>, <serpent@netnomad.com>,\n'
#  '    <jm@netnoteinc.com>, <bwsuvada@netnow.com>, <smallbusiness@netnoir.com>\n'
#  'Cc: <roberts@netnomics.com>, <jocelyn@netnovations.com>,\n'
#  '    <jm7@netnoteinc.com>, <sparklewright@netnoir.com>, '
#  '<hellenlmn@netnow.com>\n'
#  'From: "Special Buy" <SpecialBuy@tuxtla.com>\n'
#  'Subject: Protect Your Computer With Norton Systemworks 2002\n'
#  'Date: Tue, 04 Jun 2002 06:34:00 -1700\n'
#  'MIME-Version: 1.0\n'
#  'X-Keywords: \n'
#  'Content-Type: text/html; charset="iso-8859-1"\n'
#  'Content-Transfer-Encoding: quoted-printable\n'
#  '\n'
#  '<html>\n'
#  '\n'
#  '<head>\n'
#  '<meta http-equiv=3D"Content-Language" content=3D"en-us">\n'
#  '<meta http-equiv=3D"Content-Type" content=3D"text/html; charset=3Dwindows-=\n'
#  '1252">\n'
#  '<meta name=3D"GENERATOR" content=3D"Microsoft FrontPage 4.0">\n'
#  '<meta name=3D"ProgId" content=3D"FrontPage.Editor.Document">\n'
#  '<title>Norton System Works </title>\n'
#  '</head>\n'
#  '\n'
#  '<body>\n'
#  '\n'
#  '<table border=3D"1" width=3D"100%" cellspacing=3D"0" cellpadding=3D"0">\n'
#  '  <tr>\n'
#  '    <td width=3D"100%">\n'
#  '      <table border=3D"0" width=3D"100%" cellspacing=3D"0" cellpadding=3D"=\n'
#  '0" bgcolor=3D"#800000">\n'
#  '        <tr>\n'
#  '          <td width=3D"100%">\n'
#  '            <p align=3D"center"><b><font face=3D"Baskerville Old Face" col=\n'
#  'or=3D"#ffffff" size=3D"6">Norton\n'
#  '            System Works</font></b>\n'
#  '          </td>\n'
#  '        </tr>\n'
#  '      </table>\n'
#  '      <table border=3D"0" width=3D"100%" cellspacing=3D"0" cellpadding=3D"=\n'
#  '0" bgcolor=3D"#FFCC00">\n'
#  '        <tr>\n'
#  '          <td width=3D"100%">\n'
#  '            <table cellSpacing=3D"0" cellPadding=3D"0" width=3D"100%" bgCo=\n'
#  'lor=3D"#800000" border=3D"0">\n'
#  '              <tbody>\n'
#  '                <tr>\n'
#  '                  <td width=3D"100%">\n'
#  '                    <table cellSpacing=3D"0" cellPadding=3D"0" width=3D"10=\n'
#  '0%" bgColor=3D"#ffcc00" border=3D"0">\n'
#  '                      <tbody>\n'
#  '                        <tr>\n'
#  '                          <td width=3D"100%">\n'
#  '                            <p align=3D"center"><b><span class=3D"body-tex=\n'
#  't"><font face=3D"Times New Roman" color=3D"#000080" size=3D"4">A\n'
#  '                            complete problem-solving suite for advanced us=\n'
#  'ers\n'
#  '                            and small businesses.</font></span></b>\n'
#  '                          </td>\n'
#  '                        </tr>\n'
#  '                      </tbody>\n'
#  '                    </table>\n'
#  '                  </td>\n'
#  '                </tr>\n'
#  '              </tbody>\n'
#  '            </table>\n'
#  '          </td>\n'
#  '        </tr>\n'
#  '      </table>\n'
#  '      <table border=3D"0" width=3D"100%">\n'
#  '        <tr>\n'
#  '          <td width=3D"31%">\n'
#  '            <p align=3D"center"><img border=3D"0" src=3D"http://www.usavem=\n'
#  'ore.net/Images/nortonsystemworks.jpg" width=3D"105" height=3D"133"></td>\n'
#  '          <td width=3D"69%">\n'
#  '            <table border=3D"0" width=3D"100%">\n'
#  '              <tr>\n'
#  '                <td width=3D"100%">\n'
#  '                  <p align=3D"left"><b><font face=3D"Times New Roman" colo=\n'
#  'r=3D"#0000ff" size=3D"4">Norton\n'
#  '                  System Works Features:</font></b></td>\n'
#  '              </tr>\n'
#  '            </table>\n'
#  '            <ul>\n'
#  '              <li><font face=3D"Times New Roman" size=3D"3"><b>Norton Anti=\n'
#  'Virus</b>\n'
#  '                protects your PC from virus threats</font>\n'
#  '              <li><font face=3D"Times New Roman" size=3D"3"><b>Norton Util=\n'
#  'ities</b>\n'
#  '                optimizes PC performance and solves problems</font>\n'
#  '              <li><font face=3D"Times New Roman" size=3D"3"><b>Norton Clea=\n'
#  'nSweep</b>\n'
#  '                cleans out Internet clutter</font>\n'
#  '              <li><font face=3D"Times New Roman" size=3D"3"><b>GoBack</b> =\n'
#  'by Roxio\n'
#  '                provides quick and easy system recovery</font>\n'
#  '              <li><font face=3D"Times New Roman" size=3D"3"><b>Norton Ghos=\n'
#  't</b>\n'
#  '                clones and upgrades your system easily</font>\n'
#  '              <li><font face=3D"Times New Roman" size=3D"3"><b>WinFax</b> =\n'
#  '<b>Basic</b>\n'
#  '                sends and receives professional-looking faxes</font></li>\n'
#  '            </ul>\n'
#  '          </td>\n'
#  '        </tr>\n'
#  '      </table>\n'
#  '      <table border=3D"0" width=3D"100%">\n'
#  '        <tr>\n'
#  '          <td width=3D"100%">\n'
#  '            <p align=3D"center"><b><font face=3D"Britannic Bold" color=3D"=\n'
#  '#0000ff" size=3D"5"><a href=3D"http://abel.math.umu.sea636149key=3D9658952=\n'
#  '1061636149index=3DA21r7P6qW61636149.2895625@www.usavemore.net">Order\n'
#  '            Today</a></font></b></td>\n'
#  '        </tr>\n'
#  '        <tr>\n'
#  '          <td width=3D"100%">\n'
#  '            <p align=3D"center"><b><font face=3D"Times New Roman" size=3D"=\n'
#  '5">$300.00 +\n'
#  '            Value</font></b></td>\n'
#  '        </tr>\n'
#  '      </table>\n'
#  '      <table border=3D"0" width=3D"100%" cellspacing=3D"0" cellpadding=3D"=\n'
#  '0" bgcolor=3D"#FFCC00">\n'
#  '        <tr>\n'
#  '          <td width=3D"100%">\n'
#  '            <p align=3D"center"><font face=3D"Times New Roman" color=3D"#0=\n'
#  '00080" size=3D"6"><b>Your\n'
#  '            Price- $29.99</b></font></p>\n'
#  '          </td>\n'
#  '        </tr>\n'
#  '      </table>\n'
#  '      <table border=3D"0" width=3D"100%" cellspacing=3D"0" cellpadding=3D"=\n'
#  '0" bgcolor=3D"#800000">\n'
#  '        <tr>\n'
#  '          <td width=3D"100%">&nbsp;</td>\n'
#  '        </tr>\n'
#  '      </table>\n'
#  '    </td>\n'
#  '  </tr>\n'
#  '</table>\n'
#  '\n'
#  '<p align=3D"center"><center><a href=3D"http://abel.math.umu.seq64438key=3D=\n'
#  '9658952107164438index=3DA21r7P6qW7164438.53342402@www.usavemore.net/remove=\n'
#  '"><font face=3D"Times New Roman" size=3D"3">Click\n'
#  'here</font></a><font face=3D"Times New Roman" size=3D"3"> to unsubscribe f=\n'
#  'rom these\n'
#  'mailings.</font></center></p>\n'
#  '\n'
#  '</body>\n'
#  '\n'
#  '</html>\n'
#  '\n'
#  '\n'
#  '\n')
# ('From DataTapes@sdpacific.com  Fri Aug  2 16:30:52 2002\n'
#  'Return-Path: <DataTapes@sdpacific.com>\n'
#  'Delivered-To: yyyy@localhost.netnoteinc.com\n'
#  'Received: from localhost (localhost [127.0.0.1])\n'
#  '\tby phobos.labs.netnoteinc.com (Postfix) with ESMTP id EAC2944101\n'
#  '\tfor <jm@localhost>; Fri,  2 Aug 2002 11:30:40 -0400 (EDT)\n'
#  'Received: from mail.webnote.net [193.120.211.219]\n'
#  '\tby localhost with POP3 (fetchmail-5.9.0)\n'
#  '\tfor jm@localhost (single-drop); Fri, 02 Aug 2002 16:30:40 +0100 (IST)\n'
#  'Received: from 200.161.144.56 ([216.248.36.154])\n'
#  '\tby webnote.net (8.9.3/8.9.3) with SMTP id OAA03320\n'
#  '\tfor <jm@netnoteinc.com>; Fri, 2 Aug 2002 14:31:37 +0100\n'
#  'Message-Id: <200208021331.OAA03320@webnote.net>\n'
#  'Received: from [42.47.39.56] by mta6.snfc21.pbi.net with SMTP; Aug, 02 2002 '
#  '6:13:54 AM +0700\n'
#  'Received: from [26.84.34.94] by smtp4.cyberec.com with smtp; Aug, 02 2002 '
#  '5:04:41 AM +0400\n'
#  'Received: from unknown (HELO f64.law4.hotmail.com) (13.61.40.178) by '
#  'ssymail.ssy.co.kr with smtp; Aug, 02 2002 4:12:37 AM -0800\n'
#  'From: Mag DataTape Buyer <DataTapes@sdpacific.com>\n'
#  'To: none@webnote.net\n'
#  'Cc: \n'
#  'Subject: We BUY Your NEW & USED Magnetic Media or Backup Data Cartridges\n'
#  'Sender: Mag DataTape Buyer <DataTapes@sdpacific.com>\n'
#  'Mime-Version: 1.0\n'
#  'Date: Fri, 2 Aug 2002 06:30:12 -0700\n'
#  'X-Mailer: Microsoft Outlook Express 5.50.4522.1200\n'
#  'Content-Type: text/html; charset="iso-8859-1"\n'
#  '\n'
#  '<html>\n'
#  '<head>\n'
#  '<title>Untitled Document</title>\n'
#  '<meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">\n'
#  '</head>\n'
#  '\n'
#  '<body bgcolor="#FFFFFF" text="#000000">\n'
#  '\n'
#  '<table width="648" border="0" cellpadding="0" cellspacing="0" height="688">\n'
#  '  <tr> \n'
#  '    <td width="5" height="112"></td>\n'
#  '    <td width="641" valign="top"><b>Thank you in advance for taking the time '
#  'to \n'
#  '      review this email. </b> \n'
#  '      <p><font color="#FF0000">I am not selling anything.</font> Allow our '
#  'liquidation \n'
#  '        service to convert your problem inventory into quick cash. Please '
#  'contact \n'
#  '        me right away if you have any of these and/or other data media '
#  'available. \n'
#  '        We are a leader in the industry for liquidation and recycling of '
#  'these \n'
#  '        materials. Our network of outlets for your <font '
#  'color="#FF0000">EXCESS</font>, \n'
#  '        <font color="#FF0000">OVERSTOCKED</font>, or <font '
#  'color="#FF0000">SURPLUS</font> \n'
#  '        consumables allows us to provide the maximum amount of residual '
#  'value \n'
#  '        for your inventory - NEW and USED.</p>\n'
#  '    </td>\n'
#  '    <td width="2"></td>\n'
#  '  </tr>\n'
#  '  <tr> \n'
#  '    <td height="21" width="5"></td>\n'
#  '    <td width="641"></td>\n'
#  '    <td width="2"></td>\n'
#  '  </tr>\n'
#  '  <tr>\n'
#  '    <td height="179" width="5"></td>\n'
#  '    <td valign="top" width="641"> \n'
#  '      <table width="100%" border="0" cellpadding="0" cellspacing="0">\n'
#  '        <tr> \n'
#  '          <td width="589" height="179" valign="top"> \n'
#  '            <table width="100%" border="1" height="193">\n'
#  '              <tr> \n'
#  '                <td width="19%" bgcolor="#FFFFCC"><font '
#  'color="#000000">Product</font></td>\n'
#  '                <td width="22%">Brand</td>\n'
#  '                <td width="29%" bgcolor="#FFFFCC">Product</td>\n'
#  '                <td width="30%">Brand</td>\n'
#  '              </tr>\n'
#  '              <tr> \n'
#  '                <td width="19%" bgcolor="#FFFFCC"><font size="2" '
#  'color="#000000">Super \n'
#  '                  DLT</font></td>\n'
#  '                <td width="22%"><font size="2">Any</font></td>\n'
#  '                <td width="29%" bgcolor="#FFFFCC"><font '
#  'size="2">9840</font></td>\n'
#  '                <td width="30%"><font size="2">Any</font></td>\n'
#  '              </tr>\n'
#  '              <tr> \n'
#  '                <td width="19%" bgcolor="#FFFFCC"><font size="2" '
#  'color="#000000">4mm, \n'
#  '                  150m, 125m </font></td>\n'
#  '                <td width="22%"><font size="2">Any</font></td>\n'
#  '                <td width="29%" bgcolor="#FFFFCC"><font '
#  'size="2">DC6525</font></td>\n'
#  '                <td width="30%"><font size="2">Any</font></td>\n'
#  '              </tr>\n'
#  '              <tr> \n'
#  '                <td width="19%" bgcolor="#FFFFCC"><font size="2" '
#  'color="#000000">DLT \n'
#  '                  IV </font></td>\n'
#  '                <td width="22%"><font size="2">Any</font></td>\n'
#  '                <td width="29%" bgcolor="#FFFFCC"><font '
#  'size="2">LTO</font></td>\n'
#  '                <td width="30%"><font size="2">Ultrium</font></td>\n'
#  '              </tr>\n'
#  '              <tr> \n'
#  '                <td width="19%" bgcolor="#FFFFCC"><font size="2" '
#  'color="#000000">4mm, \n'
#  '                  120m, 90m </font></td>\n'
#  '                <td width="22%"><font size="2">Name brands</font></td>\n'
#  '                <td width="29%" bgcolor="#FFFFCC"><font '
#  'size="2">DC9250</font></td>\n'
#  '                <td width="30%"><font size="2">Any</font></td>\n'
#  '              </tr>\n'
#  '              <tr> \n'
#  '                <td width="19%" bgcolor="#FFFFCC"><font size="2" '
#  'color="#000000">DLT \n'
#  '                  III &amp; XT</font></td>\n'
#  '                <td width="22%"><font size="2">Quantum, Maxell, '
#  'Fuji</font></td>\n'
#  '                <td width="29%" bgcolor="#FFFFCC"><font size="2">1200\' '
#  "&amp; 2400' \n"
#  '                  Reel</font></td>\n'
#  '                <td width="30%"><font size="2">Tape any</font></td>\n'
#  '              </tr>\n'
#  '              <tr> \n'
#  '                <td width="19%" bgcolor="#FFFFCC"><font size="2" '
#  'color="#000000">3570 \n'
#  '                  </font></td>\n'
#  '                <td width="22%"><font size="2">IBM</font></td>\n'
#  '                <td width="29%" bgcolor="#FFFFCC"><font size="2">8mm, 170m, '
#  '230m</font></td>\n'
#  '                <td width="30%"><font size="2">AIT w/ chip, '
#  'Mammoth</font></td>\n'
#  '              </tr>\n'
#  '              <tr> \n'
#  '                <td width="19%" bgcolor="#FFFFCC"><font size="2" '
#  'color="#000000">DLT \n'
#  '                  Cleaning Tape </font></td>\n'
#  '                <td width="22%"><font size="2">Any</font></td>\n'
#  '                <td width="29%" bgcolor="#FFFFCC"><font size="2">Optical '
#  'Media \n'
#  '                  5.2 GB or higher</font></td>\n'
#  '                <td width="30%"><font size="2">Hewlett Packard, '
#  'etc.</font></td>\n'
#  '              </tr>\n'
#  '              <tr> \n'
#  '                <td width="19%" bgcolor="#FFFFCC"><font size="2" '
#  'color="#000000">3590 \n'
#  '                  </font></td>\n'
#  '                <td width="22%"><font size="2">Imation, IBM</font></td>\n'
#  '                <td width="29%" bgcolor="#FFFFCC"><font size="2">8mm, '
#  '112m</font></td>\n'
#  '                <td width="30%"><font size="2">Maxell, Sony, Exabyte, '
#  'Imation</font></td>\n'
#  '              </tr>\n'
#  '              <tr> \n'
#  '                <td width="19%" bgcolor="#FFFFCC"><font size="2" '
#  'color="#000000">TK70</font></td>\n'
#  '                <td width="22%"><font size="2">Any</font></td>\n'
#  '                <td width="29%" bgcolor="#FFFFCC"><font size="2">Zip &amp; '
#  'Jaz</font></td>\n'
#  '                <td width="30%"><font size="2">Any</font></td>\n'
#  '              </tr>\n'
#  '            </table>\n'
#  '          </td>\n'
#  '        </tr>\n'
#  '      </table>\n'
#  '    </td>\n'
#  '    <td width="2"></td>\n'
#  '  </tr>\n'
#  '  <tr>\n'
#  '    <td height="335" width="5"></td>\n'
#  '    <td height="335" width="641"> Your &quot;junk&quot; could turn into cash '
#  '- \n'
#  '      We pay for all shipping expenses. Just email your list of supplies to '
#  'me \n'
#  "      or any questions you may have, and you'll be contacted right away with "
#  'a \n'
#  '      bid. I can email or fax you a copy of our purchasing process to ensure '
#  'your \n'
#  '      transaction is handled efficiently and professionally - and that your '
#  'payment \n'
#  '      will be prompt and accurate! \n'
#  '      <p>Thank you again and I look forward to doing business with you in '
#  'the future. \n'
#  '      </p>\n'
#  '      <p>Norm Hutton<br>\n'
#  '      </p>\n'
#  '      <p>SD Pacific <br>\n'
#  '       If you are interested, please visit our <a '
#  'href="http://64.251.22.98/sdpacific/smm">website.</a>\n'
#  '       </p>\n'
#  '      <p><font size="2">This message is sent in compliance with the new '
#  'e-mail \n'
#  '        bill: SECTION 301, Paragraph (a)(2)(C) of s.1618. And also in '
#  'compliance \n'
#  '        with the proposed Federal legislation for commercial e-mail '
#  '(H.R.4176 \n'
#  '        - SECTION 101Paragraph (e)(1)(A)) AND S. 1618 TITLE III SEC. 301. To '
#  'be \n'
#  '        removed from our mailing list, simply by replying this email with '
#  'Subject: Remove. </font></p>\n'
#  '    </td>\n'
#  '    <td height="335" width="2"></td>\n'
#  '  </tr>\n'
#  '</table>\n'
#  '</body>\n'
#  '</html>\n'
#  '\n')
# ('From gort44@excite.com  Mon Jul 22 18:39:55 2002\n'
#  'Return-Path: <gort44@excite.com>\n'
#  'Delivered-To: yyyy@localhost.netnoteinc.com\n'
#  'Received: from localhost (localhost [127.0.0.1])\n'
#  '\tby phobos.labs.netnoteinc.com (Postfix) with ESMTP id 50F47440C9\n'
#  '\tfor <jm@localhost>; Mon, 22 Jul 2002 13:39:54 -0400 (EDT)\n'
#  'Received: from dogma.slashnull.org [212.17.35.15]\n'
#  '\tby localhost with IMAP (fetchmail-5.9.0)\n'
#  '\tfor jm@localhost (single-drop); Mon, 22 Jul 2002 18:39:54 +0100 (IST)\n'
#  'Received: from mansourgroup.com ([217.52.250.178]) by dogma.slashnull.org\n'
#  '    (8.11.6/8.11.6) with ESMTP id g6MFifI09046 for <webmaster@efi.ie>;\n'
#  '    Mon, 22 Jul 2002 16:44:41 +0100\n'
#  'Message-Id: <200207221544.g6MFifI09046@dogma.slashnull.org>\n'
#  'Received: from iwon-com.mr.outblaze.com (CHN-NH-DC2 [61.11.72.15]) by\n'
#  '    mansourgroup.com with SMTP (Microsoft Exchange Internet Mail Service\n'
#  '    Version 5.5.2653.13) id 3WY4D2HG; Sun, 21 Jul 2002 20:44:41 +0300\n'
#  'To: <ameritex@netway.at>\n'
#  'From: "sue" <gort44@excite.com>\n'
#  'Subject: Build a great future\n'
#  'Date: Sun, 21 Jul 2002 13:49:05 -1600\n'
#  'MIME-Version: 1.0\n'
#  'Content-Type: text/plain; charset="Windows-1252"\n'
#  'Content-Transfer-Encoding: 7bit\n'
#  '\n'
#  'Easy 30-50% Return?\n'
#  '\n'
#  'Learn how you can receive a monthly check for 3, 4, or 5%\n'
#  'a month until your initial investment is paid off...then a\n'
#  'monthly check for over 4% a month for years to come...\n'
#  '\n'
#  "We know it sounds impossible, but it's happening today.\n"
#  '\n'
#  'For complete information on this \n'
#  'multi-trillion dollar industry:\n'
#  '\n'
#  'http://www.page4life.org/users/69chevelle/\n'
#  '++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n'
#  'To Opt Out:\n'
#  '\n'
#  'Please go to our "OPT OUT" website:\n'
#  '\n'
#  'http://www.page4life.org/users/69chevelle/optout.html\n'
#  '\n'
#  '\n')
# ('From jm@netnoteinc.com  Mon Jun 24 17:05:04 2002\n'
#  'Return-Path: yyyy@netnoteinc.com\n'
#  'Delivery-Date: Sun May 19 21:09:44 2002\n'
#  'Received: from mandark.labs.netnoteinc.com ([213.105.180.140]) by\n'
#  '    dogma.slashnull.org (8.11.6/8.11.6) with ESMTP id g4JK9he27944 for\n'
#  '    <jm@jmason.org>; Sun, 19 May 2002 21:09:43 +0100\n'
#  'Received: from mx4.mail.yahoo.com ([198.78.28.10]) by\n'
#  '    mandark.labs.netnoteinc.com (8.11.2/8.11.2) with SMTP id g4JK9gD16427 '
#  'for\n'
#  '    <jm@netnoteinc.com>; Sun, 19 May 2002 21:09:42 +0100\n'
#  'Date: Sun, 19 May 2002 21:09:42 +0100\n'
#  'Message-Id: <200205192009.g4JK9gD16427@mandark.labs.netnoteinc.com>\n'
#  'From: yyyy@netnoteinc.com\n'
#  'To: yyyy@netnoteinc.com\n'
#  'Subject: You Won $30 Dollars !\n'
#  'MIME-Version: 1.0\n'
#  'X-Keywords: \n'
#  'Content-Type: text/html\n'
#  '\n'
#  '<html>\n'
#  '<body bgcolor="#003300">\n'
#  '<P align=center><FONT color=#ffffff size=5>Congratulations, \n'
#  "You Won $30 Free<BR>Today At The Internet's Best &amp; Most<BR>Trusted "
#  'On-Line \n'
#  'Casino!</FONT></P>\n'
#  '<P align=center><FONT color=#669966><FONT color=#ffffff size=4>To Collect '
#  'Your \n'
#  '$30 Cash </FONT><A \n'
#  'href="http://81.9.8.41"><FONT \n'
#  'size=4>Click Here!</FONT></A></FONT></P>\n'
#  '<P align=center><A \n'
#  'href="http://81.9.8.41"><IMG \n'
#  'alt="Click Here To Collect Your $30 Dollars Free And Start Playing!" \n'
#  'src="http://members.triposd.uk%81900955key=96589521081900955index=A21r7P6qW81900955.79048@%77%77%77.%70%72%65%73%74%69%67%65%63%61%73%69%6e%6f.%63%6f%6d/%70ic/%70%72e%76ie%77%73/%62i%67/%62%6cac%6b%6aac%6b.%6a%70%67" \n'
#  'border=0></A></P>\n'
#  '<P align=center>&nbsp;</P>\n'
#  '<P align=center><FONT color=#ffffff size=5>To Collect Your $30 Cash '
#  '</FONT><A \n'
#  'href="http://81.9.8.41"><FONT \n'
#  'size=5>Click Here!</FONT></A></P>\n'
#  '<P align=center>&nbsp;</P>\n'
#  '<P align=center><A \n'
#  'href="http://81.9.8.41"><IMG \n'
#  'alt="Click Here To Collect Your $30 Dollars Free And Start Playing!" \n'
#  'src="http://members.triposd.uk%21362822key=96589521021362822index=A21r7P6qW21362822.4140327@%77%77%77.%70%72%65%73%74%69%67%65%63%61%73%69%6e%6f.%63%6f%6d/%70ic/a%77a%72%64%73/%67om%5f%74o%70ca%73i%6eo%5f%64a%72%6b%31.%67i%66" \n'
#  'border=0></A></P>\n'
#  '<P align=center>&nbsp;</P>\n'
#  '<P align=center>&nbsp;</P>\n'
#  '<P align=center>&nbsp;</P>\n'
#  '<P>\n'
#  '<form name="form" method="post" '
#  'action="http://81.9.8.41/r/process_cleanlist.php">\n'
#  '<DIV align=center> \n'
#  '            <table width="391" border="1" cellspacing="0" cellpadding="0" '
#  'align="center" bordercolor="#000000">\n'
#  '              <tr> \n'
#  '                <td> \n'
#  '                  <table width="400" border="0" cellspacing="0" '
#  'cellpadding="2" bgcolor="#cccccc">\n'
#  '                    <tr> \n'
#  '                      <td>\n'
#  '            <P><font face="Arial, Helvetica, sans-serif" size="2">This '
#  'message is sent in compliance of the new \n'
#  '            e-mail bill:<BR>SECTION 301 Per Section 301, Paragraph (a)(2)(C) '
#  'of \n'
#  '            S. 1618,<BR>Further transmissions to you by the sender of this '
#  'email \n'
#  '            maybe<BR>stopped at no cost to you by entering your email '
#  'address \n'
#  '            to<BR>the form in this email and clicking submit to be \n'
#  '            automatically<BR>   \n'
#  '                                    \n'
#  '                               removed. </font><FONT \n'
#  '            face="Arial, Helvetica, sans-serif" size=2>To be Removed from '
#  'our \n'
#  '            Opt-In mailing list. Please enter your email address in the '
#  'provided \n'
#  '            box below and click remove, thank you. \n'
#  '      </FONT></P></td>\n'
#  '                    </tr>\n'
#  '                  </table>\n'
#  '                  <table width="400" border="0" cellspacing="0" '
#  'cellpadding="0" bgcolor="#cccccc">\n'
#  '                    <tr> \n'
#  '                      <td> \n'
#  '                        <div align="center"> \n'
#  '                          <input type="hidden" name="subject" '
#  'value="REMOVE">\n'
#  '                          <input name="email" size="30" \n'
#  '           >\n'
#  '                          <input type="submit" name="Submit" '
#  'value="REMOVE">\n'
#  '                        </div>\n'
#  '                      </td>\n'
#  '                    </tr>\n'
#  '                  </table>\n'
#  '                  <div align="center"></div>\n'
#  '                  <div align="center"></div>\n'
#  '                  <table width="400" border="0" cellspacing="0" '
#  'cellpadding="0" bgcolor="#cccccc">\n'
#  '                    <tr> \n'
#  '                      <td> \n'
#  '                        <div align="center"><font face="Arial, Helvetica, '
#  'sans-serif" size="1">Your \n'
#  '                          E-mail Address Will Be Immediately Removed From '
#  'All Mailing Lists</font></div>\n'
#  '                      </td>\n'
#  '                    </tr>\n'
#  '                  </table>\n'
#  '                </td>\n'
#  '              </tr>\n'
#  '            </table></DIV>\n'
#  '        </form>\n'
#  '<P>&nbsp;</P>\n'
#  '</P>\n'
#  '</body>\n'
#  '</html>\n'
#  '\n')

# %% [markdown]
# ## Preprocessing
# We just get the header of the email, and if it's spam or not

# %%
for fn in glob.glob(path):
    is_spam = 'ham' not in fn  # the relative path, the dir it's named ham if it's not spam
    with open(fn, 'r') as file:
        try:
            for line in file:
                if line.startswith('Subject: '):  # get just the subject
                    subject = re.sub(f'^Subject: ', '', line).strip()  # remove the leading subject
                    data.append((subject, is_spam))
        except UnicodeDecodeError:
            print(fn, 'UnicodeDecodeError (skip)')
# Out:
# ./dataset/spam_2/spam_2/00645.dd7d8ec1eb687c5966c516b720fcc3d5 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00886.9bd2063c3d984a66958a6195ffb97849 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01013.c6cf4f54eda63230389baccc02702034 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00043.9331daf0bd865aa657cb02cbcd06173b UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00271.7105f4998a88cbf4036403f61ba60d65 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00136.870132877ae18f6129c09da3a4d077af UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01233.010677fced50f4aecb67fba70701bcf5 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01072.ac604802c74de2ebc445efc827299b96 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01379.0d39498608cd170bbbc8cd33ffd18e35 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00951.f7044a1b178dc3dcff44932f840b8805 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00214.39bd955c9db013255c326dbcbb4f2f86 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00069.27497d5d2f92837805b67e2bf31dfc71 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01064.50715ffeb13446500895836b77fcee09 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01235.2e8191ab7ddffa2290e04f9ce0422041 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00579.d94454f0e596c00bf22ce1f315427143 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00328.47ba83d868220761b2ff71ce39d91a37 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01386.9398d616dfc3d67fb10e95d911768b39 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00359.90bec90ebeaf05f024f48594e7d7b0d5 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00117.9f0ba9c35b1fe59307e32b7c2c0d4e61 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00397.dc85d97361fbed3637f8db56d4c9c92d UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00040.d9570705b90532c2702859569bf4d01c UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00642.f213f657ab630999a8d34c26060d79fc UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00853.ee1fe2f2d16e8b27be79a670b8597252 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00319.2702ee4100f722328afc52a1a6f1dc26 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00395.74aee42fac915ca758047506ec59a21f UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00024.621bea2c6e0ebb2eb7ac00a38dfe6b00 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01259.b4dff1ed93bc931b271888cd42e41b85 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01167.2ac57a0189fa2b8713202b84e587b707 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00028.60393e49c90f750226bee6381eb3e69d UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01301.91269fd2b14a1fa0f183ca60953b99af UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01353.369f79f8f31f3b18bdb5d1006207b52e UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00329.47e3728483bdcad34227e601eb348836 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01125.46ca779f86e1dd0a03c3ffc67b57f55e UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00742.2700b00dc2dcc121ee0a1322040de188 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00374.b174d1e94449f519f3ceba87e7cefea7 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/01170.0f6cbb8149f3e19d1b3054960e2cceb5 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00239.91d2d5c0e8827c4a42cb24733a0859fa UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00789.ffe4e3c5dc50f5a9ac33a653b5f8b566 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00475.3d497c7d96c51986316db566756ff35a UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00135.9996d6845094dcec94b55eb1a828c7c4 UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00274.192bd3848a65302344dff2d7c0d3f08a UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/00680.e8df67f239cb166c5a8a78401eeeb1ba UnicodeDecodeError (skip)
# ./dataset/spam_2/spam_2/
UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0264.a1183a59e4f0a71e80378d9404a3212f UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1184.152999961bd0606fb0dcb6d6f95cc96d UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1398.02fd0caad73d10ee02aebd13b761f135 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/2193.8220cdccae38ad8e4984999416bc3c92 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0205.84f75723dcf7639ed057a32283048bdf UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/2460.8a782dd603bfe327c2f7adadf590a094 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0326.703aa5be82f6586d348723b732176418 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0495.5c4fb5aab57f610e00c4d3b951216f16 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1502.1376704c3bd9c110fe3a5d0768745d91 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0521.56b24a33e65cd045de37e6bec5ec30e3 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0225.80a615200726ed2da1bfd347dcfd648c UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1655.7a0d7700a207ef6f66686f94b02c7a8f UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/2396.8126a8ee1ebb7fe484a5709f96192b02 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0806.2eae7f9f133274ed400a215174b7de1d UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1285.b9998969053e427bd4c4c0c6e68518ec UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0228.b83f2f4ef114c69d9ca927d1082b393f UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1303.b8fb03a2de8615f9287086ccc71a4282 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0656.dd2af7ab5d99adf717056893adb12a20 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0808.426e30e31a3d3fab634e31e8aeb30c34 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0178.8405bbe39a5eb6c1814e3c16602099a4 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0469.8b40f778677e8d001ca14bcc4268b41b UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0347.0e43f8ba3aadeed419f512188e5d8aa4 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1340.763507dad3b921f972640d4d76172f7e UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1119.ce22f4a2ffbc03cd2625cb10ba561058 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/2393.9ba2bbda6af818512632047ddd5aea4a UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0008.20bc0b4ba2d99aae1c7098069f611a9b UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0457.dc1691cbb334cc33a1f1eb3060b8e02e UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0773.e1edafa86a1670e9515d4d9c1bb288c9 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0321.b100345ae7b5e980f41d9c6e0ff3159a UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/2445.631e9fa95e78d7f56fce09a4e6da56fd UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1360.18758d232e8b6937d5d62ce0e0aa2d8e UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0146.2d301a1e07672538d669f5e571180d32 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0267.218a528c448166d39f853cf75d8890dd UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0207.f7d2d40df256d6caea05314f5334a959 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0289.cb9c0595bddae2c25357ce5c9fbaf687 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0551.5bdfb0c299c60e442e39346dc08bad68 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/2439.c8c3aa25791710ac30aaaa49cb276f12 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1131.7f31a18433046205b44e6b46f9677f9a UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0638.70122b70a334560fdbc450b6516bf752 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1452.81f3e3d1b40f978cd3c0125e7020dd17 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0673.1850e124a4ef3beb85071e67d7f8bf6d UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1013.8355d120301841c6b601bee02bb4c14f UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/0799.eb9fe164fe9541253b4ab806626ab171 UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/2109.094078fcb88b4e1fa5eb9fc67ba998bc UnicodeDecodeError (skip)
# ./dataset/easy_ham/easy_ham/1333.e9f5229e15c55a75e02a92fe42324bce UnicodeDecodeError (skip)

# %%
pprint(data[:5])
# Out:
# [('Life-Time upgrades for FREEq4i1i6p8', True),
#  ('Protect Your Computer With Norton Systemworks 2002', True),
#  ('We BUY Your NEW & USED Magnetic Media or Backup Data Cartridges', True),
#  ('Build a great future', True),
#  ('You Won $30 Dollars !', True)]

# %% [markdown]
# ## Math background
#
# ### Total probability theorem
# Let $A$ be a partition, for any event $B$ we have
# $$ \bigcap_i A_i = \emptyset $$
# $$ B = \bigcup_i (A_i \cap B) $$
# Therefore
# $$ P(B) = \sum P(B|A_i)P(A_i) $$
#
# ### Bayes theorem
# $$ P(A|B) = \frac{P(A \cap B)}{P(B)} = \frac{P(B|A)P(A)}{P(B)} $$
#
# ### Naive bayes
# For this approach we are interested in knowing the probability of some event $S$ given some features $x_1,\dots,x_n$, mathematically $P(S|X_1=x_1,\dots,X_n=x_n)$. Using the bayes theorem we have
#
# $$ P(S|X) = \frac{P(X|S)P(S)}{P(X)} = \frac{P(X|S)P(S)}{P(X|S)P(S) + P(X|\overline S)P(\overline S)} $$
#
# In naive bayes, we make the assumption that $x_i$ are independent each other and $P(S)=P(\overline S)$. With this assumptions we have that
#
# $$P(X_1=x_1,\dots,X_n=x_n|S) = \prod P(X_i=x_i|S)$$
# $$P(S|X) = \frac{P(X|S)}{P(X|S) + P(X|\overline S)} $$
#
# To compute $P(X_i=x_i|S)$ we use
#
# $$P(X_i=x_i|S) = \frac{k + |\{x | x \in S\}|}{2k + |S|} $$
#
# We use the pseudocount $k$ to smoth the probability.
#
# ### Float-point calculation
# $$ \prod p_i = \exp(\sum log (p_i)) $$

# %%
def tokenize(msg):
    msg = msg.lower()
    words = re.findall("[a-z0-9']+", msg)  
    return set(words)  # remove duplicates

# %%
print(data[0][0])
tokenize(data[0][0])
# Out:
# Life-Time upgrades for FREEq4i1i6p8
# {'for', 'freeq4i1i6p8', 'life', 'time', 'upgrades'}

# %%
def count_words(X_train, y_train):
    counts = defaultdict(lambda: [0, 0])  # by default a list [0, 0]
    for text, is_spam in zip(X_train, y_train):
        for word in tokenize(text):
            counts[word][0 if is_spam else 1] += 1
    return counts

# %%
def word_probs(counts, spam_count, non_spam_count, k):
    return [(w, 
             (w_in_spam + k) / (2*k + spam_count), 
             (w_in_non_spam + k) / (2*k + non_spam_count))
             for w, (w_in_spam, w_in_non_spam) in counts.items()]

# %%
def word_proba(word_probs, msg, k=0.5):
    predictable_words = tokenize(msg)
    log_prob_if_spam = 0.0
    log_prob_if_not_spam = 0.0
    for w, p_spam, p_not_spam in word_probs:
        if w in predictable_words:
            log_prob_if_spam += math.log(p_spam)
            log_prob_if_not_spam += math.log(p_not_spam)
        else:
            log_prob_if_spam += math.log(1 - p_spam)
            log_prob_if_not_spam += math.log(1 - p_not_spam)
    prob_spam = math.exp(log_prob_if_spam)
    prob_not_spam = math.exp(log_prob_if_not_spam)
    return prob_spam / (prob_spam + prob_not_spam)

# %%
class BernoulliNB:
    
    def fit(self, X_train, y_train, k=0.5):
        counts = count_words(X_train, y_train)
        spam_count = len([y for y in y_train if y])
        not_spam_count = len(y_train) - spam_count
        self.word_probs = word_probs(counts, spam_count, not_spam_count, k)
        self.k = k
        
    def transform(self, X_test):
        return [word_proba(self.word_probs, msg, self.k) for msg in X_test]

# %%
X = [d[0] for d in data]
y = [d[1] for d in data]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf = BernoulliNB()
clf.fit(X_train, y_train)
y_pred = clf.transform(X_test)

# %%
y_pred = [True if y > 0.5 else False for y in y_pred]

# %%
print(confusion_matrix(y_test, y_pred))
f1_score(y_test, y_pred)
# Out:
# [[744  62]
#  [ 68 388]]
# 0.8565121412803532
